# %% [markdown]
# ## Data from data.ca.gov
# Last update: 9 Dec 2020
# last backup: 6 Dec 2020
#
# **Introduction**
# - what this document is
# - purpose: interesting plots of data, forcast when stay at home order will change
# - calculation of ICU % avaliablity is questioned, see link below
#
# This jupyterlab note book is an analysis of the data some CoVid-19 data from the California open data portal and the United States Department of Health and Human Services (HHS).  The purose of the analysis is to look at trends in the data and provide short term extrapolations.  The state uses various metrics to make heath decisions and issure orders for public health and this notebook will look at the matrics as they apply to Ventura country and Southern California.
#
# The state of California instituded colored tears for each county and the restrictions were based on the color.  Later the state modified the guideance to regional areas with the couther california region comprised of 10 counties.
#
#
# regional
#
# Hospitals are required to submit information on the total number of available staffed ICU beds daily. This includes both existing staffed ICU beds and staffed ICU surge beds. To calculate regional ICU capacity the total number of adult ICU beds is calculated by removing neonatal ICU beds (NICU) and pediatric intensive care unit beds (PICU) as well as standardizing current adult ICU capacity. Consistent with the goal of the Regional Stay Home Order, this calculation ensures that sufficient ICU bed capacity is available for COVID and non-COVID related conditions.
#
# As of December 4, 2020 the ICU capacity is calculated as described above.
#
#
# Disease	COVID-19
# Virus strain	SARS-CoV-2
# Location	United States
# First outbreak	Wuhan, Hubei, China[1]
# Index case	Chicago, Illinois (earliest known arrival)[2]
# Everett, Washington (first case report)[3]
#
#
# Misinformation related to the COVID-19 pandemic
# https://en.wikipedia.org/wiki/Misinformation_related_to_the_COVID-19_pandemic
#
# COVID Tracking Project
# https://en.wikipedia.org/wiki/COVID_Tracking_Project
#
# When did US students return from Europe?
# Thousands of American students in the thick of study abroad programs are getting some unexpected lessons in coping with a crisis, with some ordered to return home immediately and others stuck in a wait-and-see mode as the coronavirus spreads.
#
# For the University of Texas, the World Health's Organization's declaration Wednesday of a global virus pandemic was the last straw – it immediately suspended all education abroad programs globally and told students they must return home by March 30.
#
#
#
# The COVID-19 Forecast Hub
# https://covid19forecasthub.org/
#
#
# **History of Covid in CA**
# - origin
# - first CA cases
# - repatriation flights
# - Sacramento, SF other spread
# - 1st lock down
# - 2nd lock down
# - regional lockdown
#
# COVID-19 pandemic in the United States
# https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_United_States
#
#
#
# Timeline of the COVID-19 pandemic in the United States
# https://en.wikipedia.org/wiki/Timeline_of_the_COVID-19_pandemic_in_the_United_States
#
#
#
#
# A history of the COVID-19 pandemic in California is [here](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_California) and [here](https://en.wikipedia.org/wiki/COVID-19_pandemic_in_the_San_Francisco_Bay_Area) on wikipedia.
#
#
# Stay Home Order
# On March 19, 2020, an Executive Order (PDF) and Public Health Order (PDF) directed all Californians to stay home except to go to an essential job or to shop for essential needs. It was modified on May 4, 2020.
#
# Limited Stay Home Order
# As of November 21, 2020, Californians in counties in the Tier 1/Widespread (purple) tier are directed to stop non-essential activities between 10PM and 5AM. To find out if this order applies to your county, see the county map.
#
# Blueprint for a Safer Economy
# On August 28, 2020, the State released the Blueprint for a Safer Economy to permit gradual reopening of certain businesses and activities.
#
# Regional Stay Home Order – NEW
# The Regional Stay Home Order (PDF), announced December 3, 2020, and a supplemental order, signed December 6, 2020, will go into effect at 11:59 PM the day after a region has been announced to have less than 15% ICU availability. The supplemental order clarifies retail operations and goes into effect immediately. They prohibit private gatherings of any size, close sector operations except for critical infrastructure and retail, and require 100% masking and physical distancing in all others.
#
# Once triggered, these orders will remain in effect for at least 3 weeks. After that period, they will be lifted when a region’s projected ICU capacity meets or exceeds 15%. This will be assessed on a weekly basis after the initial 3 week period.
#
#
#
# **Data source**
# - where does the data come from?
# - what fields are being used
#
# Southern California county health department metrics or data:
# - Imperial
#  - http://www.icphd.org/health-information-and-resources/healthy-facts/covid-19/covid-19-data/
# - Inyo
#  - https://www.inyocounty.us/covid-19
# - Los Angeles
#  - http://dashboard.publichealth.lacounty.gov/covid19_surveillance_dashboard/
# - Mono
#  - https://coronavirus.monocounty.ca.gov/
# - Orange
#  - https://occovid19.ochealthinfo.com/coronavirus-in-oc
#  - https://data-ocpw.opendata.arcgis.com/search?tags=health
# - Riverside
#  - https://www.rivcoph.org/coronavirus
#  - https://coronavirus-countyofriverside.hub.arcgis.com/
# - San Bernardino
#  - https://sbcovid19.com/
#  - https://sbcph.maps.arcgis.com/apps/opsdashboard/index.html#/44bb35c804c44c8281da6d82ee602dff
# - San Diego
#  - https://www.sandiegocounty.gov/content/sdc/hhsa/programs/phs/community_epidemiology/dc/2019-nCoV/status.html
# - San Luis Obispo
#  - https://www.emergencyslo.org/en/covid19.aspx
# - Santa Barbara
#  - https://publichealthsbc.org/data/
# - Ventura
#  - https://www.venturacountyrecovers.org/
#
#
#
#
#
# https://www.venturacountyrecovers.org/
#
#
#
# **Analysis method**
# Plotting 7 day moving average for most of the data
# icu_beds_total = icu_covid_patients + icu_available_beds + other_ICU_patients
# icu_percent_available_beds = 100*(icu_available_beds/icu_beds_total)
#
# icu_beds_total and other_ICU_patients is missing from the state data
#
# Could get this data from Health data.gov
# HomeCOVID-19 Reported Patient Impact and Hospital Capacity by Facility Data Dictionary
# COVID-19 Reported Patient Impact and Hospital Capacity by Facility Data Dictionary
# Need names of hospitals in each county.
#
# Also need to look at each county health board data depository if available
#
#
#
# **Analysis**
# - Data preview and validation
# - plots of selected data
# - cases, hosptiations, ICU and deaths
# - ratio
# - look at running X=21 or 14 day cumsum of cases vs hosp. vs icu vs deaths
#
# Correlation between cases and hostitalizations.
#
# plot trajectory and extrapolate the trends
#
# The Government Operations Agency sponsors data.ca.gov, a statewide open data portal created to improve collaboration, expand transparency and lead to innovation and increased effectiveness. The Agency’s open data efforts, which support data analysis and using existing data to improve state operations, align with the Eureka Institute’s Lean process improvement program and its pilot work in data-driven performance improvement.
#
# https://data.ca.gov/group/covid-19
#
#
# New Regional Stay Home Order
# To preserve our health care system, the Regional Stay Home Order goes into effect if intensive care unit (ICU) capacity drops below 15% in a region. Counties in the region will be subject to new restrictions.
#
# A regional stay at home order was announced for California if ICU capacity drops below 15%.
#
#
# Regional Stay Home Order – NEW
# The Regional Stay Home Order [PDF](https://www.gov.ca.gov/wp-content/uploads/2020/12/12.3.20-Stay-at-Home-Order-ICU-Scenario.pdf), announced December 3, 2020, and a [supplemental order](https://www.cdph.ca.gov/Programs/CID/DCDC/Pages/COVID-19/supplement-regional-stay-at-home-order.aspx), signed December 6, 2020, will go into effect at 11:59 PM the day after a region has been announced to have less than 15% ICU availability. The supplemental order clarifies retail operations and goes into effect immediately. They prohibit private gatherings of any size, close sector operations except for critical infrastructure and retail, and require 100% masking and physical distancing in all others.
#
# Once triggered, these orders will remain in effect for at least 3 weeks. After that period, they will be lifted when a region’s projected ICU capacity meets or exceeds 15%. This will be assessed on a weekly basis after the initial 3 week period. Learn more about these orders.
#
# The Regional Stay Home Order goes into effect if intensive care unit (ICU) capacity drops below 15% in a region. Counties in the region will be subject to new restrictions.  looking at statics for each region, starting with Southern California.  Regions are:
#  - Northern California: Del Norte, Glenn, Humboldt, Lake, Lassen, Mendocino, Modoc, Shasta, Siskiyou, Tehama, Trinity
#  - Bay Area: Alameda, Contra Costa, Marin, Monterey, Napa, San Francisco, San Mateo, Santa Clara, Santa Cruz, Solano, Sonoma
#  - Greater Sacramento: Alpine, Amador, Butte, Colusa, El Dorado, Nevada, Placer, Plumas, Sacramento, Sierra, Sutter, Yolo, Yuba
#  - San Joaquin Valley: Calaveras, Fresno, Kern, Kings, Madera, Mariposa, Merced, San Benito, San Joaquin, Stanislaus, Tulare, Tuolumne
#  - Southern California: Imperial, Inyo, Los Angeles, Mono, Orange, Riverside, San Bernardino, San Diego, San Luis Obispo, Santa Barbara, Ventura
#
# <img src="RegionsMap.png" width="400"/>
#
#
# Wed, December 9, 2020, 5:46 PM PST
# California’s Lake Tahoe is temporarily shutting down to outside tourists, the latest economic blow as a deadly surge in coronavirus cases is forcing millions in America’s most populous state back under lockdown restrictions.
#
# Large swathes of California went back under the strict lockdown rules over the weekend, with restaurants forced to halt outdoor dining, personal care businesses ordered to close and stores operating at reduced capacity. Residents are asked to stay home except for essential activities, and hotels are barred from accepting most out-of-state guests.
#
# On Tuesday, the greater Sacramento region, which comprises the Lake Tahoe area, joined the group of counties under lockdown because capacity in hospital intensive care units has fallen below 15%.
#
#
# Other data sources and references:
# https://www.npr.org/sections/health-shots/2020/12/09/944379919/new-data-reveal-which-hospitals-are-dangerously-full-is-yours
# https://www.npr.org/sections/health-shots/2020/12/07/944021201/new-covid-19-data-release-shows-where-hospitals-around-the-country-are-filling-u
# https://github.com/CareSet/COVID_Hospital_PUF
# https://healthdata.gov/dataset/covid-19-reported-patient-impact-and-hospital-capacity-facility
# https://carlsonschool.umn.edu/mili-misrc-covid19-tracking-project
#
#
# https://healthdata.gov/sites/default/files/reported_hospital_capacity_admissions_facility-level_weekly_average_timeseries_20201207.csv
#
#
# COVID-19 County Projections
# https://itsonit.com/
#
#
#
# Updates to notebook:
# 1. 12-4-2020:  Saved to backup folder.  Added cells to examine the New Regional Stay Home Order, which went into effect on Dec 3, 2020.
# 2. 12-6-2020: added code to fix divide by zero and replace savgol_filter with pandas moveing average, since this is how the state smooths the data.  San Joaquin Valley (8.6%) and Southern California (12.5%) went under the Regional Stay Home Order on Sunday, December 6, 2020 at 11:59 PM.
#
#
# ### ToDo
# - write some code to use dates from county data rows, not unique dates.
# - validate dates - correct order, need to allign dates with data for each county, don't assume that each county uses the same dates for the date set.
# - plot new cases, hospitalization and ICU numbers
# - Rewrite into a report, need better title and clean up documentation

# %%
from datetime import datetime
from dateutil import parser
#from dateutil.parser import parse
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
#from scipy.linalg import lstsq
#from scipy import optimize
#from scipy import stats
#from scipy import signal

# %%
# get data files from https://data.ca.gov/group/covid-19  
df_CA_statewide_testing = pd.read_csv('https://data.ca.gov/dataset/efd6b822-7312-477c-922b-bccb82025fbe/resource/b6648a0d-ff0a-4111-b80b-febda2ac9e09/download/statewide_testing.csv') 
df_CA_hospitals_by_county = pd.read_csv('https://data.ca.gov/dataset/529ac907-6ba1-4cb7-9aae-8966fc96aeef/resource/42d33765-20fd-44b8-a978-b083b7542225/download/hospitals_by_county.csv')
df_CA_statewide_cases = pd.read_csv('https://data.ca.gov/dataset/590188d5-8545-4c93-a9a0-e230f0db7290/resource/926fd08f-cc91-4828-af38-bd45de97f8c3/download/statewide_cases.csv')

# save data to local drive 
df_CA_statewide_testing.to_csv('df_CA_statewide_testing.csv', index=False)
df_CA_hospitals_by_county.to_csv('df_CA_hospitals_by_county.csv', index=False)
df_CA_statewide_cases.to_csv('df_CA_statewide_cases.csv', index=False)

# %% [markdown]
# COVID-19 Case - Age DemographicsCSV Popular
# Age demographics related to the California COVID-19 response.
#
# COVID-19 Cases - Sex DemographicsCSV Popular
# Sex demographics related to the California COVID-19 response.
#
# COVID-19 Cases - Ethnicity DemographicsCSV Popular
# Ethnicity demographics related to the California COVID-19 response.

# %% [raw]
# # COVID-19 Case - Age Demographics
# df_CA_case_demographics_age = pd.read_csv('https://data.ca.gov/dataset/590188d5-8545-4c93-a9a0-e230f0db7290/resource/339d1c4d-77ab-44a2-9b40-745e64e335f2/download/case_demographics_age.csv')
# df_CA_case_demographics_age.to_csv('df_CA_case_demographics_age.csv', index=False)
#
# # COVID-19 Case - Sex Demographics
# df_CA_case_demographics_sex = pd.read_csv('https://data.ca.gov/dataset/590188d5-8545-4c93-a9a0-e230f0db7290/resource/ee01b266-0a04-4494-973e-93497452e85f/download/case_demographics_sex.csv')
# df_CA_case_demographics_sex.to_csv('df_CA_case_demographics_sex.csv', index=False)
#
# # COVID-19 Case - Ethnicity Demographics
# df_CA_case_demographics_ethnicity = pd.read_csv('https://data.ca.gov/dataset/590188d5-8545-4c93-a9a0-e230f0db7290/resource/7e477adb-d7ab-4d4b-a198-dc4c6dc634c9/download/case_demographics_ethnicity.csv')
# df_CA_case_demographics_ethnicity.to_csv('df_CA_case_demographics_ethnicity.csv', index=False)

# %% [markdown]
# The following is from COVID-19 Reported Patient Impact and Hospital Capacity by Facility
# https://healthdata.gov/dataset/covid-19-reported-patient-impact-and-hospital-capacity-facility/resource/b2ce2346-5e9b-4392
# https://healthdata.gov/dataset/covid-19-reported-patient-impact-and-hospital-capacity-facility
#
# COVID-19 Reported Patient Impact and Hospital Capacity by Facility
# The following dataset provides facility-level data for hospital utilization aggregated on a weekly basis (Friday to Thursday). These are derived from reports with facility-level granularity across two main sources: (1) HHS TeleTracking, and (2) reporting provided directly to HHS Protect by state/territorial health departments on behalf of their healthcare facilities.
#
# The hospital population includes all hospitals registered with Centers for Medicare & Medicaid Services (CMS) as of June 1, 2020. It includes non-CMS hospitals that have reported since July 15, 2020. It does not include psychiatric, rehabilitation, Indian Health Service (IHS) facilities, U.S. Department of Veterans Affairs (VA) facilities, Defense Health Agency (DHA) facilities, and religious non-medical facilities.
#
# For a given entry, the term “collection_week” signifies the start of the period that is aggregated. For example, a “collection_week” of 2020-11-20 means the average/sum/coverage of the elements captured from that given facility starting and including Friday, November 20, 2020, and ending and including reports for Thursday, November 26, 2020.
#
# Reported elements include an append of either “_coverage”, “_sum”, or “_avg”.
# - A “_coverage” append denotes how many times the facility reported that element during that collection week.
# - A “_sum” append denotes the sum of the reports provided for that facility for that element during that collection week.
# - A “_avg” append is the average of the reports provided for that facility for that element during that collection week.
#
# The file will be updated weekly. No statistical analysis is applied to impute non-response. For averages, calculations are based on the number of values collected for a given hospital in that collection week. Suppression is applied to the file for sums and averages less than four (4). In these cases, the field will be replaced with “-999,999”.
#
# This data is preliminary and subject to change as more data become available. Data is available starting on July 31, 2020.
#
# Sometimes, reports for a given facility will be provided to both HHS TeleTracking and HHS Protect. When this occurs, to ensure that there are not duplicate reports, deduplication is applied according to prioritization rules within HHS Protect.
#
# For influenza fields listed in the file, the current HHS guidance marks these fields as optional. As a result, coverage of these elements are varied.
#
# COVID-19 Reported Patient Impact and Hospital Capacity by Facility Data Dictionary
# https://healthdata.gov/covid-19-reported-patient-impact-and-hospital-capacity-facility-data-dictionary

# %% [markdown]
# The following is slow to load

# %% [raw]
# df_healthdata_gov = pd.read_csv('https://healthdata.gov/sites/default/files/reported_hospital_capacity_admissions_facility-level_weekly_average_timeseries_20201207.csv')

# %% [raw]
# df_healthdata_gov.columns

# %% [raw]
# df_healthdata_gov.head()

# %% [markdown]
# ## Data sets
#
# https://covid19.ca.gov/data-and-tools/
#
# Opening each data set and examining a few features.
#
# Since the beginning of the COVID-19 crisis, California has had to face facts and make hard decisions. Defeating COVID-19 will require collaboration between state government, local governments, research universities, technologists, citizen scientists, and other members of the public.
#
# California has collected a wide range of data to inform its response to COVID-19, and developed tools to help process and analyze that data. These data and tools are available for researchers, scientists, and technologists.
#
# They’re available as a downloadable set, and in new models and dashboards.

# %% [markdown]
# ### State wide testing
# Testing data related to the California COVID-19 response. Only PCR tests are included in this dataset, not antibody or other tests.
#
# Fields
# - date: Date reported
# - tested: Cumulative number of individuals tested for COVID-19 as reported to CDPH

# %%
df_CA_statewide_testing.columns
# Out:
# Index(['date', 'tested'], dtype='object')

# %%
df_CA_statewide_testing.head()
# Out:
#          date  tested
# 0  2020-03-18    6291
# 1  2020-03-19   11487
# 2  2020-03-20   12528
# 3  2020-03-21   13467
# 4  2020-03-22   14317

# %%
# convert dates from string to datetime format
testing_dates = []
for i in range(len(df_CA_statewide_testing)):
    testing_dates.append(datetime.strptime(str(df_CA_statewide_testing['date'][i]), '%Y-%m-%d'))

df_CA_statewide_testing.insert(0, 'datetime', testing_dates)  # insert a new column with datetime data
df_CA_statewide_testing.sort_values(by=['datetime'], inplace=True) # sort data frame by datetime

# Set the locator
locator = mdates.MonthLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%b-%Y')

plt.plot(df_CA_statewide_testing['datetime'],np.gradient(df_CA_statewide_testing['tested'].to_numpy())/1000,'+-')

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

plt.title('daily number of tests')
plt.ylabel('number of tests each day, 1k')

plt.grid()
plt.show()

# %% [markdown]
# ### Statewide cases
# This data set is case data for California COVID-19 response.  The data frame has the following fields.
# - datetime: date converted to datetime object
# - county: County for which case statistics were reported.
# - totalcountconfirmed: Cumulative number of laboratory-confirmed positive COVID-19 cases as reported by local health departments, beginning March 19, 2020.
# - totalcountdeaths: Cumulative number of COVID-related deaths as reported by local health department, beginning March 19, 2020. This determination is made by local health departments based on the cause of death reported on death certificates. It is expected that, to be counted, COVID is the cause of death or at least a contributing factor to the death. COVID-related deaths are also counted in “Positive Cases”.
# - newcountconfirmed: Number of new lab-confirmed positive COVID-19 cases reported by local health departments each day.
# - newcountdeaths: Number of new COVID-19 related deaths reported by local health departments to each day.
# - date: Date reported.

# %%
Southern_California_region = ['Imperial','Inyo','Los Angeles','Mono','Orange','Riverside',
    'San Bernardino','San Diego','San Luis Obispo','Santa Barbara','Ventura']

# %%
df_CA_statewide_cases.columns
# Out:
# Index(['county', 'totalcountconfirmed', 'totalcountdeaths',
#        'newcountconfirmed', 'newcountdeaths', 'date'],
#       dtype='object')

# %%
# convert date from string to datetime format
statewide_cases_dates = []
for i in range(len(df_CA_statewide_cases)):
    statewide_cases_dates.append(datetime.strptime(str(df_CA_statewide_cases['date'][i]), '%Y-%m-%d'))

df_CA_statewide_cases.insert(0, 'datetime', statewide_cases_dates)  # insert a new column with datetime data

# %%
county = Southern_California_region[2]
print('County: {:s}'.format(county))
# Out:
# County: Los Angeles

# %%
df_county_cases = df_CA_statewide_cases[(df_CA_statewide_cases['county'] == county)].copy()
df_county_cases.sort_values(by=['datetime'], inplace=True) # sort data frame by datetime
df_county_cases.head()
# Out:
#         datetime       county  totalcountconfirmed  totalcountdeaths  \
# 11913 2020-03-18  Los Angeles                 47.0               0.0
# 11914 2020-03-19  Los Angeles                233.0               0.0
# 11915 2020-03-20  Los Angeles                267.0               1.0
# 11916 2020-03-21  Los Angeles                322.0               2.0
# 11917 2020-03-22  Los Angeles                384.0               3.0
#
#        newcountconfirmed  newcountdeaths        date
# 11913                 47               0  2020-03-18
# 11914                186               0  2020-03-19
# 11915                 34               1  2020-03-20
# 11916                 55               1  2020-03-21
# 11917                 62               1  2020-03-22

# %%
# Set the locator
locator = mdates.MonthLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%b-%Y')

fig, ax1 = plt.subplots()
color = 'tab:red'
ax1.set_ylabel('New confirmed',color=color)
ax1.plot(df_county_cases['datetime'],df_county_cases['newcountconfirmed'].rolling(7).mean().to_numpy(),'-',color=color,label='New confirmed')

ax1.tick_params(axis='y', labelcolor=color)
plt.grid()

# instantiate a second y-axes that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:Blue'
ax2.plot(df_county_cases['datetime'],df_county_cases['newcountdeaths'].rolling(7).mean().to_numpy(),'-',color=color,label='New deaths')
ax2.set_ylabel('New deaths',color=color)
ax2.tick_params(axis='y', labelcolor=color)

# ask matplotlib for the plotted objects and their labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0.)

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

plt.title(county)
plt.show()

# %% [markdown]
# ### Hospitals by county
# This data set is hospital data for the COVID-19 response.  The fields are:
# - county: The County where the hospital is located. None of the consolidated reporters had hospitals in different counties.
# - todays_date: Report date
# - hospitalized_covid_confirmed_patients: The number of patients hospitalized in an inpatient bed who have laboratory-confirmed COVID. This is not a cumulative number. This includes all inpatients (including those in ICUs and Medical/Surgical units), and does not include patients in affiliated clinics, outpatient departments, emergency departments and overflow locations awaiting an inpatient bed. As of April 21, 2020, COVID ED patients were removed from the Hospitalized COVID count and counted separately.
# - hospitalized_suspected_covid_patients: The number of patients hospitalized in an inpatient bed without a laboratory-confirmed COVID diagnosis who, in accordance with CDC's Interim Public Health Guidance for Evaluating Persons Under Investigation (PUIs), have signs and symptoms compatible with COVID (most patients with confirmed COVID have developed fever and/or symptoms of acute respiratory illness, such as cough, shortness of breath or myalgia/fatigue). This includes all inpatients (including those in ICUs and Medical/Surgical units), and does not include patients in affiliated clinics, outpatient departments, emergency departments and overflow locations awaiting an inpatient bed. As of April 21, 2020, Suspected COVID ED patients were removed from the Hospitalized Suspected COVID count and counted separately.
# - hospitalized_covid_patients: The number of patients currently hospitalized in an inpatient bed who have suspected or confirmed COVID.
# - all_hospital_beds: The total number of beds in the facility, including all surge beds, inpatient and outpatient post-surgical beds, labor and delivery unit beds, and observation beds. This includes the total number of beds for which the hospital could provide staff and equipment and is not necessarily reflective of the beds that are staffed at the time the facility reports. This field does not include emergency department (ED) bays.
# - icu_covid_confirmed_patients: The number of laboratory-confirmed positive COVID patients that are in the ICU at the hospital. This includes all ICU beds (NICU, PICU, and adult).
# - icu_suspected_covid_patients: The number of symptomatic patients, with tests for COVID pending laboratory confirmation, that are in the ICU at the hospital. This includes all ICU beds (NICU, PICU, and adult).
# - icu_available_beds: The number of ICU beds available at the hospital. This includes all ICU beds (NICU, PICU, and adult).

# %%
df_CA_hospitals_by_county.columns
# Out:
# Index(['county', 'todays_date', 'hospitalized_covid_confirmed_patients',
#        'hospitalized_suspected_covid_patients', 'hospitalized_covid_patients',
#        'all_hospital_beds', 'icu_covid_confirmed_patients',
#        'icu_suspected_covid_patients', 'icu_available_beds'],
#       dtype='object')

# %% [markdown]
# ### get dates for data set

# %%
# convert date from string to datetime format
hospitals_by_county_dates = []
for i in range(len(df_CA_hospitals_by_county)):
    hospitals_by_county_dates.append(datetime.strptime(str(df_CA_hospitals_by_county['todays_date'][i]), '%Y-%m-%d'))

df_CA_hospitals_by_county.insert(0, 'datetime', hospitals_by_county_dates)  # insert a new column with datetime data

# %%
df_CA_hospitals_by_county.head()
# Out:
#     datetime         county todays_date  \
# 0 2020-03-29         Orange  2020-03-29
# 1 2020-03-29          Glenn  2020-03-29
# 2 2020-03-29  Santa Barbara  2020-03-29
# 3 2020-03-29         Tulare  2020-03-29
# 4 2020-03-29         Sonoma  2020-03-29
#
#    hospitalized_covid_confirmed_patients  \
# 0                                   74.0
# 1                                    NaN
# 2                                   15.0
# 3                                    6.0
# 4                                    7.0
#
#    hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 0                                  167.0                          NaN
# 1                                    NaN                          NaN
# 2                                   21.0                          NaN
# 3                                   13.0                          NaN
# 4                                   20.0                          NaN
#
# ...

# %% [markdown]
# ## Hospital capacity

# %%
county = Southern_California_region[2]
print('County: {:s}'.format(county))
# Out:
# County: Los Angeles

# %%
df_county_hospitals = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)].copy()
df_county_hospitals.sort_values(by=['datetime'], inplace=True) # sort data frame by datetime
df_county_hospitals.head()
# Out:
#       datetime       county todays_date  \
# 10  2020-03-29  Los Angeles  2020-03-29
# 82  2020-03-30  Los Angeles  2020-03-30
# 149 2020-03-31  Los Angeles  2020-03-31
# 219 2020-04-01  Los Angeles  2020-04-01
# 241 2020-04-02  Los Angeles  2020-04-02
#
#      hospitalized_covid_confirmed_patients  \
# 10                                   489.0
# 82                                   601.0
# 149                                  713.0
# 219                                  739.0
# 241                                  818.0
#
#      hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 10                                  1132.0                          NaN
# 82                                  1277.0                          NaN
# 149                                 1239.0                          NaN
# 219                                 1332.0                          NaN
# 241                                 1270.0                          NaN
#
# ...

# %%
# Set the locator
locator = mdates.MonthLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%b-%Y')

fig, ax1 = plt.subplots()

ax1.plot(df_county_hospitals['datetime'], \
         df_county_hospitals['hospitalized_covid_patients'].rolling(7).mean().to_numpy(), \
         '-k',label='hospitalized covid patients')

ax1.plot(df_county_hospitals['datetime'], \
         df_county_hospitals['icu_suspected_covid_patients'].rolling(7).mean().to_numpy() + \
         df_county_hospitals['icu_covid_confirmed_patients'].rolling(7).mean().to_numpy(), \
         '-g',label='Covid ICU patients')

ax1.plot(df_county_hospitals['datetime'], \
         df_county_hospitals['icu_available_beds'].rolling(7).mean().to_numpy(), \
         '-b',label='icu_available_beds')

ax1.set_ylabel('Covid hospitalized, ICU, ICU beds')
ax1.tick_params(axis='y')
plt.grid()

# instantiate a second y-axes that shares the same x-axis
ax2 = ax1.twinx()
# plot new cases here
color = 'tab:Red'
ax2.set_ylabel('New confirmed',color=color)
ax2.plot(df_county_cases['datetime'], \
         df_county_cases['newcountconfirmed'].rolling(7).mean().to_numpy(), \
         '-',color=color,label='New confirmed')

ax2.tick_params(axis='y', labelcolor=color)
#ax2.set_ylim((0,100))

# ask matplotlib for the plotted objects and their labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.15, 1), loc='upper left', borderaxespad=0.)

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

plt.title(county)
plt.show()

# %% [markdown]
# ## Intensive Care Unit (ICU) capacity
#
# ICU COVID Confirmed Patients
# The number of laboratory-confirmed positive COVID patients that are in the ICU at the hospital. This includes all ICU beds (NICU, PICU, and adult). Additional clarification added on June 16, 2020.
#
# ICU Suspected COVID Patients
# The number of symptomatic patients, with tests for COVID pending laboratory confirmation, that are in the ICU at the hospital. This includes all ICU beds (NICU, PICU, and adult). Additional clarification added on June 16, 2020.
#
# ICU Available Beds
# The number of ICU beds available at the hospital. This includes all ICU beds (NICU, PICU, and adult). Additional clarification added on June 16, 2020.
# Never. This is a calculated field.
#
# icu_beds_total = icu_covid_patients + icu_available_beds
# icu_percent_available_beds = 100*(icu_available_beds/icu_beds_total)
#
# ## Select county data
# Looking at the data from selected counties.  For example, Ventura, LA and Orange.

# %% [raw]
# df_county_hospitals.columns

# %% [raw]
# county = Southern_California_region[3]
# print('County: {:s}'.format(county))
#
# icu_suspected_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy()
# icu_covid_confirmed_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy()
#
# icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients
#
# icu_available_beds = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_available_beds'].to_numpy()
#
# icu_beds_total = icu_covid_patients + icu_available_beds
# icu_beds_total = np.where(icu_beds_total == 0, np.nan, icu_beds_total) # replace zero values by nan
#
# icu_percent_available_beds = 100*(icu_available_beds/icu_beds_total)

# %% [raw]
# # use pandas to calculate moving averages for selected data sets
# icu_covid_patients_mva7 = pd.Series(icu_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
# icu_available_beds_mva7 = pd.Series(icu_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()
# icu_beds_total_mva7 = pd.Series(icu_beds_total, hospitals_by_county_date).rolling(7).mean().to_numpy()
# icu_percent_available_beds_mva7 = pd.Series(icu_percent_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()

# %% [raw]
# ax1.plot(df_county_hospitals['datetime'],
#          df_county_hospitals['icu_available_beds'].rolling(7).mean().to_numpy(), \
#          '-',color=color,label='Available ICU beds')
#
# ax1.plot(df_county_hospitals['datetime'], \
#          df_county_hospitals['icu_suspected_covid_patients'].rolling(7).mean().to_numpy() + \
#          df_county_hospitals['icu_covid_confirmed_patients'].rolling(7).mean().to_numpy(), \
#          '-',color=color,label='Covid ICU patients')

# %%
# Set the locator
locator = mdates.MonthLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%b-%Y')

fig, ax1 = plt.subplots()

ax1.set_ylabel('Covid hospitalized, ICU and deathes')

ax1.plot(df_county_hospitals['datetime'], \
         df_county_hospitals['hospitalized_covid_patients'].rolling(7).mean().to_numpy(), \
         '-g',label='hospitalized covid patients')

ax1.plot(df_county_hospitals['datetime'], \
         df_county_hospitals['icu_suspected_covid_patients'].rolling(7).mean().to_numpy() + \
         df_county_hospitals['icu_covid_confirmed_patients'].rolling(7).mean().to_numpy(), \
         '-b',label='Covid ICU patients')

ax1.plot(df_county_cases['datetime'], \
         df_county_cases['newcountdeaths'].rolling(7).mean().to_numpy(), \
         '-k',label='New deaths')

plt.grid()

# instantiate a second y-axes that shares the same x-axis
ax2 = ax1.twinx()
color = 'tab:red'
ax2.plot(df_county_cases['datetime'],df_county_cases['newcountconfirmed'].rolling(7).mean().to_numpy(), \
         '-',color=color,label='New confirmed')
ax2.set_ylabel('New confirmed',color=color)
ax2.tick_params(axis='y', labelcolor=color)
#ax2.set_ylim((0,100))

# ask matplotlib for the plotted objects and their labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0.)

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

plt.title(county)
#plt.ylabel('Current number')
#plt.legend()
#plt.grid()
plt.show()

# %% [raw]
# # Set the locator
# locator = mdates.MonthLocator()  # every month
# # Specify the format - %b gives us Jan, Feb...
# fmt = mdates.DateFormatter('%b-%Y')
#
# fig, ax1 = plt.subplots()
#
# ax1.set_ylabel('Current number')
#
# ax1.plot(hospitals_by_county_date,icu_available_beds_mva7,'r-',label='Available ICU beds')
# #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_available_beds,7,0),'r-',label='Available ICU beds')
# #ax1.plot(hospitals_by_county_date[-1],icu_available_beds[-1],'r+') # plot the last point
#
# ax1.plot(hospitals_by_county_date,icu_covid_patients_mva7,'b-',label='Covid ICU patients')
# #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_covid_patients,7,0),'b-',label='Covid ICU patients')
# #ax1.plot(hospitals_by_county_date[-1],icu_covid_patients[-1],'b+')
#
# ax1.plot(hospitals_by_county_date,icu_beds_total_mva7,'k-',label='All icu beds')
# #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_beds_total,7,0),'k-',label='All icu beds')
# #ax1.plot(hospitals_by_county_date[-1],icu_beds_total[-1],'k+')
# plt.grid()
#
# # instantiate a second y-axes that shares the same x-axis
# ax2 = ax1.twinx()
# ax2.plot(hospitals_by_county_date,icu_percent_available_beds_mva7,'g-',label='% Available ICU beds')
# #ax2.plot(hospitals_by_county_date,signal.savgol_filter(icu_percent_available_beds,7,0),'g-',label='% Available ICU beds')
# ax2.plot(hospitals_by_county_date[-1],icu_percent_available_beds[-1],'g<')
#
# color = 'tab:green'
# ax2.set_ylabel('% Available ICU beds',color=color)
# ax2.tick_params(axis='y', labelcolor=color)
# #ax2.set_ylim((0,100))
#
# # ask matplotlib for the plotted objects and their labels
# lines1, labels1 = ax1.get_legend_handles_labels()
# lines2, labels2 = ax2.get_legend_handles_labels()
# ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
# ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.1, 1), loc='upper left', borderaxespad=0.)
#
# X = plt.gca().xaxis
# X.set_major_locator(locator)
# # Specify formatter
# X.set_major_formatter(fmt)
# plt.gcf().autofmt_xdate()
#
# plt.title(county)
# #plt.ylabel('Current number')
# #plt.legend()
# #plt.grid()
# plt.show()
#
# print('percent ICU beds available = {:.1f}%'.format(icu_percent_available_beds[-1]))

# %% [markdown]
# **STOPPED HERE**

# %% [markdown]
# ## Plotting new cases, hospitalized covid patients and ICU covid patients

# %%
for county in Southern_California_region:

    icu_suspected_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy()
    icu_covid_confirmed_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy()
    icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

    icu_available_beds = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_available_beds'].to_numpy()

    # use pandas to calculate moving averages for selected data sets
    icu_covid_patients_mva7 = pd.Series(icu_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_available_beds_mva7 = pd.Series(icu_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_beds_total_mva7 = pd.Series(icu_beds_total, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_percent_available_beds_mva7 = pd.Series(icu_percent_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()

    hospitalized_covid_confirmed_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['hospitalized_covid_confirmed_patients'].to_numpy()
    hospitalized_suspected_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['hospitalized_suspected_covid_patients'].to_numpy()
    hospitalized_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['hospitalized_covid_patients'].to_numpy()
    all_hospital_beds = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['all_hospital_beds'].to_numpy()

    # use pandas to calculate moving averages for selected data sets
    hospitalized_covid_confirmed_patients_mva7 = pd.Series(hospitalized_covid_confirmed_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
    hospitalized_suspected_covid_patients_mva7 = pd.Series(hospitalized_suspected_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
    hospitalized_covid_patients_mva7 = pd.Series(hospitalized_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()

    newcountconfirmed = df_CA_statewide_cases[(df_CA_statewide_cases['county'] == county)]['newcountconfirmed'].to_numpy()
    newcountdeaths = df_CA_statewide_cases[(df_CA_statewide_cases['county'] == county)]['newcountdeaths'].to_numpy()

    # use pandas to calculate moving averages for selected data sets
    newcountconfirmed_mva7 = pd.Series(newcountconfirmed, statewide_cases_date).rolling(7).mean().to_numpy()
    newcountdeaths_mva7 = pd.Series(newcountdeaths, statewide_cases_date).rolling(7).mean().to_numpy()

    # Set the locator
    locator = mdates.MonthLocator()  # every month
    # Specify the format - %b gives us Jan, Feb...
    fmt = mdates.DateFormatter('%b-%Y')

    fig, ax1 = plt.subplots()

    ax1.set_ylabel('Covid hospitalized, ICU and deathes')

    ax1.plot(hospitals_by_county_date,hospitalized_covid_patients_mva7,'r-',label='hospitalized covid patients')
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_available_beds,7,0),'r-',label='Available ICU beds')
    #ax1.plot(hospitals_by_county_date[-1],icu_available_beds[-1],'r+') # plot the last point

    ax1.plot(hospitals_by_county_date,icu_covid_patients_mva7,'b-',label='Covid ICU patients')
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_covid_patients,7,0),'b-',label='Covid ICU patients')
    #ax1.plot(hospitals_by_county_date[-1],icu_covid_patients[-1],'b+')

    ax1.plot(statewide_cases_date,newcountdeaths_mva7,'k-',label='newcountdeaths')
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_beds_total,7,0),'k-',label='All icu beds')
    #ax1.plot(hospitals_by_county_date[-1],icu_beds_total[-1],'k+')
    plt.grid()

    # instantiate a second y-axes that shares the same x-axis
    ax2 = ax1.twinx()
    color = 'tab:green'
    ax2.plot(statewide_cases_date,newcountconfirmed_mva7,'-',color=color,label='new cases confirmed')
    #ax2.plot(hospitals_by_county_date,icu_percent_available_beds_mva7,'g-',label='% Available ICU beds')
    #ax2.plot(hospitals_by_county_date,signal.savgol_filter(icu_percent_available_beds,7,0),'g-',label='% Available ICU beds')
    #ax2.plot(hospitals_by_county_date[-1],icu_percent_available_beds[-1],'g<')


    ax2.set_ylabel('New cases confirmed',color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    #ax2.set_ylim((0,100))

    # ask matplotlib for the plotted objects and their labels
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
    ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.15, 1), loc='upper left', borderaxespad=0.)

    X = plt.gca().xaxis
    X.set_major_locator(locator)
    # Specify formatter
    X.set_major_formatter(fmt)
    plt.gcf().autofmt_xdate()

    plt.title(county)
    #plt.ylabel('Current number')
    #plt.legend()
    #plt.grid()
    plt.show()

# %% [markdown]
# ## Plotting ICU covid patients and % Available ICU beds
# Southern California region

# %%
Southern_California_region = ['Imperial','Inyo','Los Angeles','Mono','Orange','Riverside',
    'San Bernardino','San Diego','San Luis Obispo','Santa Barbara','Ventura']

# %%
for county in Southern_California_region:

    icu_suspected_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy()
    icu_covid_confirmed_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy()
    icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

    icu_available_beds = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_available_beds'].to_numpy()

    icu_beds_total = icu_covid_patients + icu_available_beds
    icu_beds_total = np.where(icu_beds_total == 0, np.nan, icu_beds_total) # replace zero values by nan
    icu_percent_available_beds = 100*(icu_available_beds/icu_beds_total)

    # use pandas to calculate moving averages for selected data sets
    icu_covid_patients_mva7 = pd.Series(icu_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_available_beds_mva7 = pd.Series(icu_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_beds_total_mva7 = pd.Series(icu_beds_total, hospitals_by_county_date).rolling(7).mean().to_numpy()
    icu_percent_available_beds_mva7 = pd.Series(icu_percent_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()    

    # Set the locator
    locator = mdates.MonthLocator()  # every month
    # Specify the format - %b gives us Jan, Feb...
    fmt = mdates.DateFormatter('%b-%Y')

    fig, ax1 = plt.subplots()

    ax1.set_ylabel('Current number')

    ax1.plot(hospitals_by_county_date,icu_available_beds_mva7,'r-',label='Available ICU beds')   
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_available_beds,7,0),'r-',label='Available ICU beds')
    #ax1.plot(hospitals_by_county_date[-1],icu_available_beds[-1],'r+') # plot the last point

    ax1.plot(hospitals_by_county_date,icu_covid_patients_mva7,'b-',label='Covid ICU patients')
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_covid_patients,7,0),'b-',label='Covid ICU patients')
    #ax1.plot(hospitals_by_county_date[-1],icu_covid_patients[-1],'b+')

    ax1.plot(hospitals_by_county_date,icu_beds_total_mva7,'k-',label='All icu beds')
    #ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_beds_total,7,0),'k-',label='All icu beds')
    #ax1.plot(hospitals_by_county_date[-1],icu_beds_total[-1],'k+')
    plt.grid()  # adding this here puts the grid on the left axis
    
    # instantiate a second y-axes that shares the same x-axis
    ax2 = ax1.twinx()
    ax2.plot(hospitals_by_county_date,icu_percent_available_beds_mva7,'g-',label='% Available ICU beds')
    #ax2.plot(hospitals_by_county_date,signal.savgol_filter(icu_percent_available_beds,7,0),'g-',label='% Available ICU beds')
    ax2.plot(hospitals_by_county_date[-1],icu_percent_available_beds[-1],'g<')

    color = 'tab:green'
    ax2.set_ylabel('% Available ICU beds',color=color)
    ax2.tick_params(axis='y', labelcolor=color)
    ax2.set_ylim((0,100))

    # ask matplotlib for the plotted objects and their labels
    lines1, labels1 = ax1.get_legend_handles_labels()
    lines2, labels2 = ax2.get_legend_handles_labels()
    ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
    ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.15, 1), loc='upper left', borderaxespad=0.)

    X = plt.gca().xaxis
    X.set_major_locator(locator)
    # Specify formatter
    X.set_major_formatter(fmt)
    plt.gcf().autofmt_xdate()

    plt.title(county)
    #plt.ylabel('Current number')
    #plt.legend()
    #plt.grid()
    plt.show()
    print('percent ICU beds available = {:.1f}%'.format(icu_percent_available_beds[-1]))
# Out:
# percent ICU beds available = 0.0%
# percent ICU beds available = 50.0%
# percent ICU beds available = 29.0%
# percent ICU beds available = 100.0%
# percent ICU beds available = 22.7%
# percent ICU beds available = 14.0%
# percent ICU beds available = 17.0%
# percent ICU beds available = 39.3%
# percent ICU beds available = 74.2%
# percent ICU beds available = 69.6%
# percent ICU beds available = 30.0%

# %% [markdown]
# ## Totals for Southern California region
# need to check the math

# %%
Southern_California_region = ['Imperial','Inyo','Los Angeles','Mono','Orange','Riverside',
    'San Bernardino','San Diego','San Luis Obispo','Santa Barbara','Ventura']

# %%
# clear arrays
icu_suspected_covid_patients = np.zeros(icu_suspected_covid_patients.shape)
icu_covid_confirmed_patients = np.zeros(icu_covid_confirmed_patients.shape)
icu_available_beds = np.zeros(icu_available_beds.shape)

# sum accross all counties in the region
for county in Southern_California_region:
    icu_suspected_covid_patients += np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
    icu_covid_confirmed_patients += np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
    icu_available_beds += np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_available_beds'].to_numpy())

icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients
icu_beds_total = icu_covid_patients + icu_available_beds

# use pandas to calculate moving averages for selected data sets
icu_covid_patients_mva7 = pd.Series(icu_covid_patients, hospitals_by_county_date).rolling(7).mean().to_numpy()
icu_available_beds_mva7 = pd.Series(icu_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()
icu_beds_total_mva7 = pd.Series(icu_beds_total, hospitals_by_county_date).rolling(7).mean().to_numpy()
icu_percent_available_beds_mva7 = pd.Series(icu_percent_available_beds, hospitals_by_county_date).rolling(7).mean().to_numpy()    

# Set the locator
locator = mdates.MonthLocator()  # every month
# Specify the format - %b gives us Jan, Feb...
fmt = mdates.DateFormatter('%b-%Y')

fig, ax1 = plt.subplots()

ax1.set_ylabel('Current number')

ax1.plot(hospitals_by_county_date,icu_available_beds_mva7,'r-',label='Available ICU beds')   
#ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_available_beds,7,0),'r-',label='Available ICU beds')
#ax1.plot(hospitals_by_county_date[-1],icu_available_beds[-1],'r+') # plot the last point

ax1.plot(hospitals_by_county_date,icu_covid_patients_mva7,'b-',label='Covid ICU patients')
#ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_covid_patients,7,0),'b-',label='Covid ICU patients')
#ax1.plot(hospitals_by_county_date[-1],icu_covid_patients[-1],'b+')

ax1.plot(hospitals_by_county_date,icu_beds_total_mva7,'k-',label='All icu beds')
#ax1.plot(hospitals_by_county_date,signal.savgol_filter(icu_beds_total,7,0),'k-',label='All icu beds')
#ax1.plot(hospitals_by_county_date[-1],icu_beds_total[-1],'k+')
plt.grid()

# instantiate a second y-axes that shares the same x-axis
ax2 = ax1.twinx()
ax2.plot(hospitals_by_county_date,icu_percent_available_beds_mva7,'g-',label='% Available ICU beds')
#ax2.plot(hospitals_by_county_date,signal.savgol_filter(icu_percent_available_beds,7,0),'g-',label='% Available ICU beds')
ax2.plot(hospitals_by_county_date[-1],icu_percent_available_beds[-1],'g<')

color = 'tab:green'
ax2.set_ylabel('% Available ICU beds',color=color)
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim((0,100))

# ask matplotlib for the plotted objects and their labels
lines1, labels1 = ax1.get_legend_handles_labels()
lines2, labels2 = ax2.get_legend_handles_labels()
ax1.legend(lines1 + lines2, labels1 + labels2,loc=0)
ax1.legend(lines1 + lines2, labels1 + labels2,bbox_to_anchor=(1.15, 1), loc='upper left', borderaxespad=0.)

X = plt.gca().xaxis
X.set_major_locator(locator)
# Specify formatter
X.set_major_formatter(fmt)
plt.gcf().autofmt_xdate()

plt.title('Southern California region')
#plt.ylabel('Current number')
#plt.legend()
#plt.grid()
plt.show()    
    
print('percent ICU beds available = {:.1f}%'.format(icu_percent_available_beds[-1]))    
print('7 day MA percent ICU beds available = {:.1f}%'.format(icu_percent_available_beds_mva7[-1]))
# Out:
# percent ICU beds available = 30.0%
# 7 day MA percent ICU beds available = 36.9%

# %%
'Imperial'
'Inyo'
'Los Angeles'
'Mono'
'Orange'
'Riverside'
'San Bernardino'
'San Diego'
'San Luis Obispo'
'Santa Barbara'
'Ventura'
# Out:
# 'Ventura'

# %%
county = 'Imperial'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Imperial_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Inyo'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Inyo_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Los Angeles'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Los_Angeles_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Mono'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Mono_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Orange'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Orange_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Riverside'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Riverside_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'San Bernardino'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
San_Bernardino_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'San Diego'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
San_Diego_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'San Luis Obispo'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
San_Luis_Obispo_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Santa Barbara'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Santa_Barbara_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

county = 'Ventura'
icu_suspected_covid_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy())
icu_covid_confirmed_patients = np.nan_to_num(df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy())
Ventura_icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

# %%
Orange_icu_covid_patients
# Out:
# array([ 71., 100.,  89.,  98., 114., 102., 115., 116., 106., 100.,  83.,
#         74.,  94.,  64.,  96.,  71.,  88., 100.,  80.,  73.,  87.,  97.,
#         94., 104.,  94., 100.,  92.,  95.,  96.,  99., 100.,  92.,  87.,
#         85.,  98.,  91.,  88.,  85.,  85.,  94.,  99., 104., 102., 110.,
#        102., 127., 116., 124., 121., 135., 123., 135., 130., 130., 145.,
#        135., 131., 138., 137., 144., 132., 108., 148., 142., 141., 148.,
#        134., 141., 142., 148., 166., 160., 165., 153., 172., 177., 164.,
#        164., 159., 169., 165., 156., 149., 167., 171., 176., 174., 186.,
#        189., 199., 192., 193., 200., 212., 227., 208., 217., 215., 226.,
#        250., 251., 253., 251., 254., 251., 245., 251., 247., 256., 248.,
#        244., 223., 227., 247., 243., 240., 223., 220., 210., 213., 212.,
#        215., 201., 200., 174., 179., 183., 179., 179., 179., 183., 175.,
#        174., 162., 154., 152., 149., 163., 150., 146., 149., 136., 138.,
# ...

# %%
Imperial_icu_covid_patients+Inyo_icu_covid_patients+Los_Angeles_icu_covid_patients+Mono_icu_covid_patients+Orange_icu_covid_patients
# Out:
# array([ 447.,  595.,  650.,  660.,  662.,  743.,  754.,  765.,  777.,
#         789.,  839.,  782.,  762.,  765.,  809.,  802.,  801.,  850.,
#         793.,  785.,  797.,  821.,  826.,  841.,  834.,  828.,  789.,
#         782.,  816.,  820.,  840.,  804.,  784.,  804.,  817.,  799.,
#         780.,  782.,  761.,  751.,  735.,  698.,  707.,  711.,  704.,
#         733.,  717.,  715.,  702.,  728.,  710.,  714.,  691.,  708.,
#         740.,  724.,  703.,  720.,  726.,  712.,  722.,  675.,  710.,
#         675.,  692.,  690.,  664.,  711.,  705.,  673.,  703.,  700.,
#         690.,  681.,  702.,  685.,  665.,  661.,  670.,  689.,  660.,
#         663.,  647.,  682.,  684.,  675.,  708.,  723.,  723.,  739.,
#         732.,  776.,  811.,  858.,  878.,  858.,  885.,  858.,  876.,
#         903.,  902.,  897.,  923.,  901.,  918.,  905.,  941.,  946.,
#         939.,  969.,  915.,  914.,  921.,  956.,  981.,  900.,  915.,
# ...

# %%
Imperial_icu_covid_patients+Inyo_icu_covid_patients+Los_Angeles_icu_covid_patients+ \
    Mono_icu_covid_patients+Orange_icu_covid_patients+Riverside_icu_covid_patients+ \
    San_Bernardino_icu_covid_patients+San_Diego_icu_covid_patients+San_Luis_Obispo_icu_covid_patients+ \
    Santa_Barbara_icu_covid_patients+Ventura_icu_covid_patients
# Out:
# array([ 678.,  863.,  991.,  990., 1022., 1116., 1129., 1171., 1156.,
#        1181., 1212., 1141., 1133., 1120., 1165., 1152., 1170., 1223.,
#        1133., 1121., 1116., 1149., 1157., 1201., 1191., 1159., 1122.,
#        1126., 1159., 1150., 1192., 1163., 1149., 1162., 1183., 1166.,
#        1124., 1143., 1106., 1089., 1081., 1045., 1047., 1057., 1036.,
#        1063., 1068., 1059., 1045., 1062., 1045., 1078., 1037., 1026.,
#        1058., 1039., 1028., 1052., 1072., 1062., 1063., 1002., 1047.,
#         997., 1039., 1034., 1018., 1063., 1058., 1024., 1041., 1075.,
#        1060., 1035., 1055., 1044., 1021., 1012., 1010., 1047., 1030.,
#        1047., 1037., 1065., 1101., 1114., 1163., 1184., 1198., 1207.,
#        1219., 1277., 1325., 1391., 1426., 1392., 1400., 1403., 1432.,
#        1460., 1445., 1412., 1455., 1433., 1448., 1453., 1500., 1520.,
#        1497., 1534., 1497., 1485., 1505., 1551., 1565., 1502., 1508.,
# ...

# %% [markdown]
# ## Test code to extract data by county

# %%
# slice out data by county
county = 'Ventura'

# %%
temp_df = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]
temp_df.head()
# Out:
#       county todays_date  hospitalized_covid_confirmed_patients  \
# 6    Ventura  2020-03-29                                   24.0
# 104  Ventura  2020-03-30                                   25.0
# 161  Ventura  2020-03-31                                   21.0
# 199  Ventura  2020-04-01                                   22.0
# 268  Ventura  2020-04-02                                   27.0
#
#      hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 6                                     85.0                          NaN
# 104                                   82.0                          NaN
# 161                                   90.0                          NaN
# 199                                   96.0                          NaN
# 268                                  111.0                          NaN
#
#      all_hospital_beds  icu_covid_confirmed_patients  \
# 6                  NaN                           5.0
# ...

# %%
temp_df.tail()
# Out:
#         county todays_date  hospitalized_covid_confirmed_patients  \
# 14310  Ventura  2020-12-09                                  145.0
# 14349  Ventura  2020-12-10                                  146.0
# 14439  Ventura  2020-12-11                                  152.0
# 14488  Ventura  2020-12-12                                  173.0
# 14539  Ventura  2020-12-13                                  181.0
#
#        hospitalized_suspected_covid_patients  hospitalized_covid_patients  \
# 14310                                    7.0                        152.0
# 14349                                   12.0                        158.0
# 14439                                   11.0                        163.0
# 14488                                   11.0                        184.0
# 14539                                   11.0                        192.0
#
#        all_hospital_beds  icu_covid_confirmed_patients  \
# 14310             1218.0                          48.0
# ...

# %%
county = Southern_California_region[3]
print('County: {:s}'.format(county))

icu_suspected_covid_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_suspected_covid_patients'].to_numpy()
icu_covid_confirmed_patients = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_covid_confirmed_patients'].to_numpy()
icu_covid_patients = icu_suspected_covid_patients + icu_covid_confirmed_patients

icu_available_beds = df_CA_hospitals_by_county[(df_CA_hospitals_by_county['county'] == county)]['icu_available_beds'].to_numpy()

icu_beds_total = icu_covid_patients + icu_available_beds
icu_beds_total = np.where(icu_beds_total == 0, np.nan, icu_beds_total) # replace zero values by nan

icu_percent_available_beds = 100*(icu_available_beds/icu_beds_total)
# Out:
# County: Mono

# %%
# find the index at t1
t1 = df_weather_v2_data.index.get_loc(datetime.today() - timedelta(days=1), method='nearest')

# find the index at t2
t2 = df_weather_v2_data.index.get_loc(datetime.now(), method='nearest')

df_slice_24h = df_weather_v2_data[t1:t2]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-a05136c248b0> in <module>
#       1 # find the index at t1
# ----> 2 t1 = df_weather_v2_data.index.get_loc(datetime.today() - timedelta(days=1), method='nearest')
#       3
#       4 # find the index at t2
#       5 t2 = df_weather_v2_data.index.get_loc(datetime.now(), method='nearest')
#
# NameError: name 'df_weather_v2_data' is not defined
